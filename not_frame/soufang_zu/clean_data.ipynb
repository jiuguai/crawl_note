# %%
import pandas as pd
import pymongo
import pymysql

# %%
cli = pymongo.MongoClient('127.0.0.1',27017)
cs_zf = cli.soufang.cs_zf

# %%
data = pd.DataFrame(list(cs_zf.find()))
cli.close()
len(data)
# Out:
# 30005

# %%
df2 = data[["detail_url","address"]].groupby("detail_url").count()

# %%
df1 = data.drop_duplicates(subset=["detail_url"])
df1.reset_index(drop=True,inplace=True)
del df1["_id"]

# %%
len(df1)
# Out:
# 2195

# %%
from sqlalchemy import create_engine

# %%
df1 = df1.replace({"house_type":{"�O":"㎡"}},regex=True)

# %%
engin = create_engine("mysql://root:root@localhost:3306/soufang?charset=utf8",echo="debug")
df1.to_sql('cs_zf',engin,index=False,if_exists="replace")
# Out:
# 2018-10-21 19:41:08,804 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2018-10-21 19:41:08,805 INFO sqlalchemy.engine.base.Engine ()
# 2018-10-21 19:41:08,809 DEBUG sqlalchemy.engine.base.Engine Col ('Variable_name', 'Value')
# 2018-10-21 19:41:08,813 DEBUG sqlalchemy.engine.base.Engine Row ('sql_mode', 'STRICT_TRANS_TABLES,NO_AUTO_CREATE_USER,NO_ENGINE_SUBSTITUTION')
# 2018-10-21 19:41:08,815 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2018-10-21 19:41:08,818 INFO sqlalchemy.engine.base.Engine ()
# 2018-10-21 19:41:08,820 DEBUG sqlalchemy.engine.base.Engine Col ('DATABASE()',)
# 2018-10-21 19:41:08,824 DEBUG sqlalchemy.engine.base.Engine Row ('soufang',)
# 2018-10-21 19:41:08,829 INFO sqlalchemy.engine.base.Engine show collation where `Charset` = 'utf8mb4' and `Collation` = 'utf8mb4_bin'
# 2018-10-21 19:41:08,833 INFO sqlalchemy.engine.base.Engine ()
# ...

# %%
import json

# %%
new_cs_zu = cli.soufang.new_cs_zu

# %%
new_cs_zu.inser

# %%
json.loads(df1.to_json(orient="records"))
# Out:
# [{'address': '岳麓-滨江新城-纳爱斯阳光丽城',
#   'detail': '距长郡滨江中学公交站约694米。',
#   'detail_url': 'http://cs.zu.fang.com//chuzu/3_154459334_1.htm',
#   'house_type': '整租|4室2厅|103㎡|朝南北',
#   'price': '2800元/月',
#   'status': '',
#   'title': '滨江新城 宜居大盘阳光丽城 长郡滨江边 交通便利 小区'},
#  {'address': '雨花-高桥-西子一间',
#   'detail': '距东屯渡桥西公交站约793米。',
#   'detail_url': 'http://cs.zu.fang.com//chuzu/3_154413320_1.htm',
#   'house_type': '整租|1室1厅|50㎡|朝南',
#   'price': '1900元/月',
#   'status': '随时看房|电梯房|急租',
#   'title': '高桥 西子花苑 西子一间 上河国际 家电齐全 拎包入住'},
#  {'address': '开福-伍家岭-天健壹平方英里',
#   'detail': '距1号线开福寺站约740米，距湘雅医学院公交站约879米',
#   'detail_url': 'http://cs.zu.fang.com//chuzu/3_154561289_1.htm',
#   'house_type': '整租|8室3厅|250㎡|朝南',
#   'price': '19500元/月',
#   'status': '随时看房|急租|电梯房',
#   'title': '天健壹平方英里 写字楼 可容纳50人办公 精装修 拎包即办公'},
#  {'address': '芙蓉-袁家岭-湘域中央',
#   'detail': '距2号线袁家岭站约149米，距城市花园公交站约595米',
#   'detail_url': 'http://cs.zu.fang.com//chuzu/3_154394977_1.htm',
#   'house_type': '整租|1室1厅|53㎡|朝南',
# ...

# %%
pd.io.sql.wr

# %%
df1.to_sql('cs_zf',con,schema="mysql",index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\python\python36\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1377             else:
# -> 1378                 cur.execute(*args)
#    1379             return cur
#
# e:\python\python36\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     167
# --> 168         query = self.mogrify(query, args)
#     169
#
# e:\python\python36\lib\site-packages\pymysql\cursors.py in mogrify(self, query, args)
#     146         if args is not None:
# --> 147             query = query % self._escape_args(args, conn)
#     148
#
# TypeError: not all arguments converted during string formatting
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-8-77529c5ef708> in <module>()
# ...

# %%
df1.dtypes
# Out:
# address       object
# detail        object
# detail_url    object
# house_type    object
# price         object
# status        object
# title         object
# dtype: object
